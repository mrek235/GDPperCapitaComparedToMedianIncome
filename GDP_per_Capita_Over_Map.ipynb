# %% [markdown]
# <a href="https://colab.research.google.com/github/mrek235/GDPperCapitaComparedToMedianIncome/blob/main/GDP_per_Capita_Over_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install owid-catalog
# Install necessary libraries if not already installed
# !pip install pandas plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 35.6 MB/s eta 0:00:00
# ...

# %%
from owid import catalog
from owid.catalog import charts

# %%
#gdp_pcap = catalog.find('gdp_pcap').iloc[-1].load()
#wb = catalog.find('world_bank').load()

# %%
df
# Out:
#       entities  years  median_income_after_tax_lis
# 0    Australia   1981                     21880.08
# 1    Australia   1985                     21807.39
# 2    Australia   1989                     22009.95
# 3    Australia   1995                     20206.26
# 4    Australia   2001                     22712.27
# ..         ...    ...                          ...
# 859    Vietnam   2005                      4776.31
# 860    Vietnam   2007                      5786.49
# 861    Vietnam   2009                      6242.77
# 862    Vietnam   2011                      7335.61
# 863    Vietnam   2013                      7799.19
#
# [864 rows x 3 columns]

# %%
median_income = charts.get_data('https://ourworldindata.org/grapher/median-income-after-tax-lis')
median_income = median_income[median_income['years']==2013]
median_income.rename({'entities':'country'},axis=1,inplace=True)
entities_to_remove = ['World','Europe and Central Asia (WB)', 'European Union (27)','South Asia (WB)','Sub-Saharan Africa (WB)']
median_income = median_income[~median_income['country'].isin(entities_to_remove)]



df = charts.get_data('https://ourworldindata.org/grapher/gdp-per-capita-worldbank')
df = df[df['years']==2013]
df.rename({'entities':'country'},axis=1,inplace=True)
entities_to_remove = ['World','Europe and Central Asia (WB)', 'European Union (27)','South Asia (WB)','Sub-Saharan Africa (WB)']
df = df[~df['country'].isin(entities_to_remove)]

df = pd.merge(df,median_income,on=['country','years'])
df.rename({'median_income_after_tax_lis':'median_income'},axis=1,inplace=True)
df['median_income_compared_to_gdf'] = df['median_income'] / df['gdp_per_capita_worldbank']

# %%
# prompt: please plot gpd per capita of countries in a world map

import pandas as pd
import plotly.express as px



# Check if the necessary columns exist in the dataframe
if not all(col in df.columns for col in ['country', 'gdp_per_capita_worldbank']):
    print("Error: The dataframe must have columns named 'country' and 'gdp_per_capita'")
else:
  # Create the choropleth map
  fig = px.choropleth(df, locations="country",locationmode='country names',
                      color="median_income_compared_to_gdppc", # lifeExp is a column of gapminder
                      hover_name="country", # column to add to hover information
                      color_continuous_scale=px.colors.sequential.Plasma)

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
